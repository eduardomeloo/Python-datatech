# %% [markdown]
# <a href="https://colab.research.google.com/github/eduardomeloo/Python-datatech/blob/master/Aula_14_03_2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Pandas**

# %%
from google.colab import files
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
excel = files.upload()
# Out:
#      <input type="file" id="files-f2cde128-34b5-4275-ac4e-0fcef0db498f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f2cde128-34b5-4275-ac4e-0fcef0db498f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df_pagamento = pd.read_csv("PAGAMENTO_2023_01.csv", sep="|")
# Out:
# <ipython-input-6-aa578db586af>:1: DtypeWarning: Columns (0,1,2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_pagamento = pd.read_csv("PAGAMENTO_2023_01.csv", sep="|")

# %%
display(df_pagamento)
# Out:
#                                             DADOS
# idvenda             codigoformapagamento    valor
# 202301021025457028  1                     21.6800
# 202301021025456997  1                     52.4100
# 202301021042270889  1                     10.0000
# 202301021071421260  7                     59.0100
# ...                                           ...
# 2023013110311541076 7                       500.0
# 2023013110311541021 7                       86.09
# 202301311093326163  7                        4.79
# 20230131111488427   7                       15.35
# 202301311112718932  16                      24.75
#
# [953319 rows x 1 columns]

# %%
type(df_pagamento)
# Out:
# pandas.core.frame.DataFrame

# %%
df_pagamento.tail()
# Out:
#                         DADOS
# 2023013110311541076 7   500.0
# 2023013110311541021 7   86.09
# 202301311093326163  7    4.79
# 20230131111488427   7   15.35
# 202301311112718932  16  24.75

# %%
df_pagamento.tail(100)
# Out:
#                          DADOS
# 202301091038276312  6   599.97
# 202301091071318777  6    17.78
# 202301091095248236  7    64.17
# 20230109111121200   7    13.47
# 2023010911216340634 1    38.27
# ...                        ...
# 2023013110311541076 7    500.0
# 2023013110311541021 7    86.09
# 202301311093326163  7     4.79
# 20230131111488427   7    15.35
# 202301311112718932  16   24.75
#
# [100 rows x 1 columns]

# %%
df_pagamento.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 953319 entries, ('idvenda', 'codigoformapagamento') to (202301311112718932, 16)
# Data columns (total 1 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   DADOS   953319 non-null  object
# dtypes: object(1)
# memory usage: 51.2+ MB

# %%
df_pagamento.describe()
# Out:
#            DADOS
# count   953319.0
# unique   88035.0
# top        100.0
# freq      2226.0
